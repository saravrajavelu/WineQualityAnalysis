# %%
# Loading libraries
import pandas as pd
import matplotlib.pyplot as plt, matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
import time
import math
from IPython.display import Markdown, display
from sklearn.metrics import pairwise


# %matplotlib inline


def printmd(string):
    display(Markdown(string))

# %%
# Import data
wine = pd.read_csv('winequality-red.csv', sep = ';')

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine[[i for i in wine.columns if i != 'quality']].plot(kind = 'box', figsize = (20,20), title = 'Boxplot')

# %%
wine.corr(method = 'pearson')
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
wine['class'] = ['Low' if i <= 5 else "High" for i in wine.quality]
wine['class'].value_counts().plot(kind = 'bar')

# Dropping quality attribute
wine.drop(columns = ['quality'], inplace = True)

# %%
wine_data = wine[wine.columns[wine.columns != 'class']]
wine_label = wine[wine.columns[wine.columns == 'class']]

# %%
# Z score normalization
df_zscore = (wine_data - wine_data.mean())/wine_data.std()

# Min max normalization
df_min_max = (wine_data-wine_data.min())/(wine_data.max()-wine_data.min())

# %%
df_zscore.plot(kind ='box', figsize = (20,20))

# %%
df_min_max.plot(kind ='box', figsize = (20,20))

# %%
def euclidean_dist(x,y):
    return (math.sqrt(sum((pd.Series(x)-pd.Series(y))**2)))

#pairwise.paired_distances([x],[y], metric='euclidean')[0]

def cosine_similarity(a,b):
    a = pd.Series(a)
    b = pd.Series(b)
    return (sum(a*b)/(math.sqrt(sum(a*a))*math.sqrt(sum(b*b))))
    
    
def KNN(k, train_df, train_labels, test_df):
    out = []
    test_nums = test_df.shape[0]
    for i in range(test_nums):
        distances = train_data.apply(lambda x: pairwise.paired_distances([x],[test_df.iloc[i,:]], metric='euclidean')[0], axis = 1)
        distances_sorted = distances.sort_values().index
        distances_class = train_labels.loc[distances_sorted]['class']
        distances_class = distances_class[:k+1]
        res = distances_class.value_counts().index[0]
        out.append(res)
    return pd.Series(out)

def KNN_cosine(k, train_df, train_labels, test_df):
    out = []
    test_nums = test_df.shape[0]
    for i in range(test_nums):
        distances = train_data.apply(lambda x: cosine_similarity(x,test_df.iloc[i,:]), axis = 1)
        distances_sorted = distances.sort_values().index
        distances_class = train_labels.loc[distances_sorted]['class']
        distances_class = distances_class[:k+1]
        res = distances_class.value_counts().index[0]
        out.append(res)
    return pd.Series(out)
        
def OptimalKFinder(k_max, train_df, train_labels, test_df, test_label):
    out = {}
    for i in range(1,k_max+1):
        x = KNN(i,train_df, train_labels, test_df)
        TP, FN, FP, TN, accuracy, precision, recall = confusion(x,test_label)
        out['TP'] = out.get('TP',[]) + [TP]
        out['FN'] = out.get('FN',[]) + [FN]
        out['FP'] = out.get('FP',[]) + [FP]
        out['TN'] = out.get('TN',[]) + [TN]
        out['accuracy'] = out.get('accuracy',[]) + [accuracy]
        out['precision'] = out.get('precision',[]) + [precision]
        out['recall'] = out.get('recall',[]) + [recall]
    return pd.DataFrame(out)
        
def OptimalKFinder_cosine(k_max, train_df, train_labels, test_df, test_label):
    out = {}
    for i in range(1,k_max+1):
        x = KNN_cosine(i,train_df, train_labels, test_df)
        TP, FN, FP, TN, accuracy, precision, recall = confusion(x,test_label)
        out['TP'] = out.get('TP',[]) + [TP]
        out['FN'] = out.get('FN',[]) + [FN]
        out['FP'] = out.get('FP',[]) + [FP]
        out['TN'] = out.get('TN',[]) + [TN]
        out['accuracy'] = out.get('accuracy',[]) + [accuracy]
        out['precision'] = out.get('precision',[]) + [precision]
        out['recall'] = out.get('recall',[]) + [recall]
    return pd.DataFrame(out)
        
    
def confusion(x,y):
    if len(x) != len(y):
        return 'Length do not match'
    y = list(y)
    TP, TN, FP, FN = 0,0,0,0
    for i in range(len(x)):

        if y[i] == 'High':
            if x[i] == 'High':
                TP += 1
            else:
                FN += 1
        else:
            if x[i] == 'High':
                FP += 1
            else:
                TN += 1
    accuracy = ((TP+TN)*100)/(TP+FN+FP+TN)
    precision = (TP*100)/(TP+FP)
    recall = (TP*100)/(TP+FN)
    return TP, FN, FP, TN, accuracy, precision, recall

        
def confusion_d(x,y):
    if len(x) != len(y):
        return 'Length do not match'
    y = list(y)
    TP, TN, FP, FN = 0,0,0,0
    for i in range(len(x)):

        if y[i] == 'High':
            if x[i] == 'High':
                TP += 1
            else:
                FN += 1
        else:
            if x[i] == 'High':
                FP += 1
            else:
                TN += 1
    accuracy = ((TP+TN)*100)/(TP+FN+FP+TN)
    precision = (TP*100)/(TP+FP)
    recall = (TP*100)/(TP+FN)
    printmd(f'<table> \
            <tr> \
                <th rowspan=\'2\' colspan=\'2\'>Confusion Matrix<th> \
                <th colspan=\'2\'><center>Predicted Values</center></th> \
            </tr> \
            <tr> \
                <td>High</td> \
                <td>Low</td> \
            </tr> \
            <tr> \
                <th rowspan=\'2\'>Actual Values</th> \
                <td>High</td> \
                <td>{TP}</td> \
                <td>{FN}</td> \
            </tr> \
            <tr> \
                <td>Low</td> \
                <td>{FP}</td> \
                <td>{TN}</td> \
            </tr> \
        </table>')
    
    return TP, FN, FP, TN, accuracy, precision, recall

# %%
# Varying K - Euclidean Distance


start_time = time.time()
train_data, test_data, train_label, test_label = train_test_split(wine_data, wine_label, train_size = 0.75, test_size = 0.25) 
x_gen = OptimalKFinder(10, train_data, train_label, test_data, test_label['class'])
printmd("--- %s seconds ---" % (time.time() - start_time))
display(x_gen)

# %%
# Varying K - Euclidean Distance - Min Max


start_time = time.time()
train_data, test_data, train_label, test_label = train_test_split(df_min_max, wine_label, train_size = 0.75, test_size = 0.25) 
x_gen_mm = OptimalKFinder(10, train_data, train_label, test_data, test_label['class'])
printmd("--- %s seconds ---" % (time.time() - start_time))
display(x_gen_mm)

# %%
# Varying K - Euclidean Distance - Z score


start_time = time.time()
train_data, test_data, train_label, test_label = train_test_split(df_zscore, wine_label, train_size = 0.75, test_size = 0.25) 
x_gen_z = OptimalKFinder(10, train_data, train_label, test_data, test_label['class'])
printmd("--- %s seconds ---" % (time.time() - start_time))
display(x_gen_z)

# %%
# Varying K - Cosine Similarity

start_time = time.time()
train_data, test_data, train_label, test_label = train_test_split(wine_data, wine_label, train_size = 0.75, test_size = 0.25) 
x_cosine = OptimalKFinder_cosine(10, train_data, train_label, test_data, test_label['class'])
printmd("--- %s seconds ---" % (time.time() - start_time))
display(x_cosine)

# %%
# Varying K - Cosine Distance - Min Max

start_time = time.time()
train_data, test_data, train_label, test_label = train_test_split(df_min_max, wine_label, train_size = 0.75, test_size = 0.25) 
x_cosine_mm = OptimalKFinder_cosine(10, train_data, train_label, test_data, test_label['class'])
printmd("--- %s seconds ---" % (time.time() - start_time))
display(x_cosine_mm)

# %%
# Varying K - Cosine Distance - Z score

start_time = time.time()
train_data, test_data, train_label, test_label = train_test_split(df_zscore, wine_label, train_size = 0.75, test_size = 0.25) 
x_cosine_z = OptimalKFinder_cosine(10, train_data, train_label, test_data, test_label['class'])
printmd("--- %s seconds ---" % (time.time() - start_time))
display(x_cosine_z)

# %%
train_data, test_data, train_label, test_label = train_test_split(wine_data, wine_label, train_size = 0.75, test_size = 0.25) 
# Running KNN
start_time = time.time()
x = KNN(5, train_data, train_label, test_data)
print("--- %s seconds ---" % (time.time() - start_time))
print(x.value_counts())
TP, FN, FP, TN, accuracy, precision, recall = confusion(x,test_label['class'])
print(accuracy, precision, recall)

# %%
train_data, test_data, train_label, test_label = train_test_split(wine_data, wine_label, train_size = 0.75, test_size = 0.25) 
# Running KNN cosine
start_time = time.time()
x = KNN_cosine(5, train_data, train_label, test_data)
print("--- %s seconds ---" % (time.time() - start_time))
print(x.value_counts())
TP, FN, FP, TN, accuracy, precision, recall = confusion(x,test_label['class'])
print(accuracy, precision, recall)

# %%
# Running KNN with z-score normalized data

train_data, test_data, train_label, test_label = train_test_split(df_zscore, wine_label, train_size = 0.75, test_size = 0.25) 

start_time = time.time()
x = KNN(5, train_data, train_label, test_data)
print("--- %s seconds ---" % (time.time() - start_time))
print(x.value_counts())
TP, FN, FP, TN, accuracy, precision, recall = confusion(x,test_label['class'])
print(accuracy, precision, recall)

# %%
# Running KNN with min-max normalized data

train_data, test_data, train_label, test_label = train_test_split(df_min_max, wine_label, train_size = 0.75, test_size = 0.25) 

start_time = time.time()
x = KNN(1, train_data, train_label, test_data)
print("--- %s seconds ---" % (time.time() - start_time))
print(x.value_counts())
TP, FN, FP, TN, accuracy, precision, recall = confusion(x,test_label['class'])
print(accuracy, precision, recall)

# %%
printmd('# Comparing with off the shelf KNN classifiers')
# Create and fit a nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
cv_scores = []
train_data, test_data, train_label, test_label = train_test_split(wine_data, wine_label, train_size = 0.75, test_size = 0.25, random_state = 42) 
for i in range(1,100):
    knn = KNeighborsClassifier(algorithm='auto',  metric='minkowski', 
                               metric_params=None, n_jobs=-1, n_neighbors=i, p=2,
                           weights='uniform')
    knn.fit(train_data, train_label['class']) 
    scores = cross_val_score(knn, train_data, train_label['class'].ravel(), cv=10, scoring='accuracy')
    #x = knn.predict(test_data)
    #TP, FN, FP, TN, accuracy, precision, recall = confusion(x,test_label['class'])
    #print(i, accuracy, precision, recall)
    cv_scores.append(scores.mean())

# %%
for i,x in enumerate(cv_scores):
    print(i,x)

# %%
x

# %%
x.plot()

# %%
wine = pd.read_csv("winequality-red.csv")
wine_X = wine.iloc[:, 0:(wine.shape[1] - 1)]
wine_X_norm = (wine_X - wine_X.mean()) / (wine_X.max() - wine_X.min())
